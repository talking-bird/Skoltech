# %% [markdown]
# # Problem Set 1 (96 points)

# %% [markdown]
# ### Important information
#
#
# 1. We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.
#
# 2. Please submit the single Jupyter Notebook file, where only Python and Markdown/$\LaTeX$ are used. Any hand-written solutions inserted by photos or in any other way **are prohibitive and will not be graded**. If you will have any questions about using Markdown, ask them!

# %% [markdown]
# ## Problem 1 (Theoretical tasks) (36 pts)

# %% [markdown]
# 1.
# - (1 pts) What are the constants $C_1$ and $C_2$ such that $C_1 \|x\|_{1} \leq \|x\|_{\infty} \leq C_2 \| x\|_{1}$ for any vector $x$
# - (5 pts) Prove that $\| U A \|_F = \| A U \|_F = \| A \|_F$ for any unitary matrix $U$.
# - (5 pts) Prove that $\| U A \|_2 = \| A U \|_2 = \| A \|_2$ for any unitary matrix $U$.

# %% [markdown]
# 2.
#
# - (5 pts) Using the results from the previous subproblem, prove that $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$. Hint: SVD will help you.
# - (5 pts) Show that for any $m, n$ and $k \le \mathrm{min}(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$. In other words, show that the previous inequality is not strict.
# - (5 pts) Prove that if $A \in \mathbb{R}^{n \times n}$ - diagonalizable matrix, then $\det(\exp(A)) = \exp(\mathrm{trace}(A))$.
# Hint: $\exp(S^{-1}AS) = \sum\limits_{k=0}^{\infty}\frac{(S^{-1}AS)^k}{k!} = S^{-1}\exp(A)S$, moreover $\exp(D) = \mathrm{diag}(\exp(d_1), \exp(d_2), ..., \exp(d_n))$ where $D = \mathrm{diag}(d_1, d_2, ..., d_n)$ - diagonal matrix with diagonal values $d_1, d_2, ..., d_n$
#
# - (5 pts) Prove that $\| A B \|_2 \le \| A \|_2 \| B \|_F$.

# %% [markdown]
# 3.
#
# - (2 pts) Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$. Find a pseudoinverse of $UU^*$
# - (3 pts) Compute pseudoinverse of the matrix analytically
#
# $$ A = \begin{bmatrix} 2\\ 3\\ \vdots\\ \sqrt{5n-1} \end{bmatrix} \begin{bmatrix} -1 & 1 & -1 & \ldots & (-1)^{n} \end{bmatrix} $$

# %% [markdown]
# ---

# %% [markdown]
# #### 1.

# %% [markdown]
# ##### 1.(1 pts) What are the constants $C_1$ and $C_2$ such that $C_1 \|x\|_{1} \leq \|x\|_{\infty} \leq C_2 \| x\|_{1}$ for any vector $x$

# %% [markdown]
# $\|x\|_{p} \ = \left ( \sum_{i=1}^n |x_i|^p \right )^{1/p} \\
# \|x\|_{1} \ = \left ( \sum_{i=1}^n |x_i| \right ) \\
# \|x\|_{\infty} = max_i |x_i|$

# %% [markdown]
# $ \|x\|_{1}=\sum_{i=1}^n |x_i| \leq \sum_{i=1}^n max_i |x_i| = n \cdot \|x\|_{\infty} \Rightarrow \dfrac{1}{n}\|x\|_{1} \leq \|x\|_{\infty}   $

# %% [markdown]
# $ \|x\|_{\infty} = max_i |x_i| = |x_k|,k \in [1,n] \\ |x_k| \leq \sum_{i=1}^n |x_i|=\|x \|_1 \Rightarrow
# \|x\|_{\infty} \leq 1 \cdot \|x \|_1$

# %% [markdown]
# Thus, $C_1 = \dfrac{1}{n}, C_2 = 1$, where n is a length of the vector $x$

# %% [markdown]
# ##### 2.(5 pts) Prove that $\| U A \|_F = \| A U \|_F = \| A \|_F$ for any unitary matrix $U$.

# %% [markdown]
# Unitary matrix: $U^*U=I$, where * is a conjugate transpose, $I$ is an identity matrix

# %% [markdown]
# Frobenius norm: $\|A\|_F \overset{\underset{\mathrm{def}}{}}{=} \left ( \sum_{i,j=1}^{n,m} |a_{i j}|^2 \right )^{1/2} = \left ( \sum_{i,j=1}^{n,m} a_{ij}a^*_{ji} \right )^{1/2} = \left ( \text{Tr}(AA^*) \right )^{1/2} $,where Tr is a trace of matrix \

# %% [markdown]
# $\| U A\|^2_F = \text{Tr} ( (UA)^* UA)= \text{Tr} ( (A^*U^* UA) = \text{Tr} ( A^*(U^*U)A)=\text{Tr} ( A^*A)= \|A\|^2_F $ \
# $\|A U\|^2_F = \text{Tr} ( (AU)^* AU)= \text{Tr} ( (U^*A^* AU) =|\text{Cyclic property}|= \text{Tr} (A^*AUU^*)=\text{Tr} ( A^*A)= \|A\|^2_F $

# %% [markdown]
# ##### 3.(5 pts) Prove that $\| U A \|_2 = \| A U \|_2 = \| A \|_2$ for any unitary matrix $U$.

# %% [markdown]
# $\|A\|_2=\displaystyle \max_{ x \neq 0}\dfrac{\|Ax\|_2}{\|x\|_2}; \quad \|Ux\|_2 = \|x\|_2 \ (!)$

# %% [markdown]
# $\|UA\|_2=\displaystyle \max_{ x \neq 0}\dfrac{\|UAx\|_2}{\|x\|_2}=(!)=\displaystyle \max_{ x \neq 0}\dfrac{\|Ax\|_2}{\|x\|_2}=\|A\|_2$ \
# $\|AU\|_2=\displaystyle \max_{ x \neq 0}\dfrac{\|AUx\|_2}{\|x\|_2}=|Ux=y|=\displaystyle \max_{ y \neq 0}\dfrac{\|Ay\|_2}{\|U^*y\|_2}=(!)=\displaystyle \max_{ y \neq 0}\dfrac{\|Ay\|_2}{\|y\|_2}=\|A\|_2$

# %% [markdown]
# #### 2.

# %% [markdown]
# singular value decomposition (SVD) : \
#
#
# **Theorem**. Any matrix $A\in \mathbb{C}^{n\times m}$ can be written as a product of three matrices:
# $$ A = U \Sigma V^*, $$
#
# where
#
# - $U$ is an $n \times n$ unitary matrix
# - $V$ is an $m \times m$ unitary matrix
# - $\Sigma$ is a diagonal matrix with non-negative elements $\sigma_1 \geq \ldots, \geq \sigma_{\mathrm{min} (m,n)}$ on the diagonal.
#
# Moreover, if $\text{rank}(A) = r$, then $\sigma_{r+1} = \dots = \sigma_{\min (m,n)} = 0$ \\
# $\|A\|_2=\sigma_1(A)=\sqrt{\lambda_{\text{max}}(A^*A)}$, where $\sigma_1(A)$ is the largest singular value of the matrix $A$ and $^*$ is a conjugate transpose of the matrix.

# %% [markdown]
# ##### 1.(5 pts) Using the results from the previous subproblem, prove that $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$. Hint: SVD will help you.

# %% [markdown]
# $ \|A\|_F^2 = \text{Tr} ( A^*A)=\sum_{i=1}^n \lambda_i ( A^*A) $, where $\lambda_i$ is a matrix eigenvalue

# %% [markdown]
# rank of real and symmetric matrix is the total number of nonzero eigenvalues. \
# $\mathrm{rank}(AB)\leq \mathrm{min}(\mathrm{rank}(A),\mathrm{rank}(B)) \Rightarrow \mathrm{rank}(A^*A)\leq \mathrm{min}(\mathrm{rank}(A^*), \mathrm{rank}(A))\leq \mathrm{rank}(A)=r$

# %% [markdown]
# Solution: $\|A\|_F^2 =\sum_{i=1}^n \lambda_i ( A^*A) \leq r \cdot \lambda_\text{max} ( A^*A) = r \cdot \|A\|_2^2 \Rightarrow \| A \|_F \le \sqrt{r} \| A \|_2$

# %% [markdown]
# ##### 2.(5 pts) Show that for any $m, n$ and $k \le \mathrm{min}(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$. In other words, show that the previous inequality is not strict.

# %% [markdown]
# If $A = U \Sigma V^*$ (SVD), where $\Sigma$ is a diagonal matrix with $\sigma_1=\sigma_2=...=\sigma_k=1$ and others =0, then \
# $ \|A\|_F^2 = \sum_{i=1}^k 1^2=k$, \
# $ \|A\|_2 = \sigma_1(A)=1$, \
# $ \|A\|_F = \sqrt{k} \cdot 1 = \sqrt{rank(A)} \cdot \|A\|_2$

# %% [markdown]
# #####3.(5 pts) Prove that if $A \in \mathbb{R}^{n \times n}$ - diagonalizable matrix, then $\det(\exp(A)) = \exp(\mathrm{trace}(A))$.
# Hint: $\exp(S^{-1}AS) = \sum\limits_{k=0}^{\infty}\frac{(S^{-1}AS)^k}{k!} = S^{-1}\exp(A)S$, moreover $\exp(D) = \mathrm{diag}(\exp(d_1), \exp(d_2), ..., \exp(d_n))$ where $D = \mathrm{diag}(d_1, d_2, ..., d_n)$ - diagonal matrix with diagonal values $d_1, d_2, ..., d_n$

# %% [markdown]
# diagonalization of the matrix: $D = S^{-1}AS$, where $S = [v_1 \ v_2 \ v_3 \ ... \ v_n]$ - matrix of A's eigenvectors

# %% [markdown]
# $D = \text{diag}(\lambda_1,\lambda_2,..,\lambda_n)$, where $\lambda_i$ is an eigenvalue of matrix A \\
# $\exp(D) = \text{diag} (e^{\lambda_1},e^{\lambda_2},...,e^{\lambda_n})$ \\
# $trace(A)=\sum_i^n a_{ii}, \ trace(D)=\sum_i^n \lambda_{i}$

# %% [markdown]
# Solution: $\det(\exp(A)) = \det(\exp(SDS^{-1}))= \det(S\exp(D)S^{-1})=\det(S)\det(\exp(D))\det(S^{-1}) = \det(\exp(D))=\det( \text{diag} (e^{\lambda_1},e^{\lambda_2},...,e^{\lambda_n}) )=\prod_{i=1}^n e^{\lambda_i} =e^{\sum \lambda_i} = \exp(\mathrm{trace}(D))=\exp(\mathrm{trace}(S^{-1}AS))=\exp(\mathrm{trace}(A))$

# %% [markdown]
# #####4.(5 pts) Prove that $\| A B \|_2 \le \| A \|_2 \| B \|_F$.

# %% [markdown]
# $ \|A\|_F^2 = \text{Tr} ( A^*A)=\sum_{i=1}^n \lambda_i ( A^*A) $, where $\lambda_i$ is a matrix eigenvalue

# %% [markdown]
# $\|A\|_2^2=\lambda_{\text{max}}(A^*A) \leq \sum_{i=1}^n \lambda_i ( A^*A) = \|A\|_F^2 \rightarrow \|A\|_2 \leq \|A\|_F$

# %% [markdown]
# $\|AB\|^2_F=\text{trace}((A^*A)(B^*B))=|A^*A=X,B^*B=Y|=\text{trace}(XY)
# =\text{trace}(Q\Sigma Q^∗Y)
# =\text{trace}(\Sigma (Q^∗YQ))
# =\text{trace}(\Sigma Z)
# =\sum_{i=1}^n \lambda_i(X)\cdot z_{i,i}
# \leq \sum_{i=1}^n \lambda_\text{max}(X)\cdot z_{i,i}
# =\|A\|^2_2⋅\sum_{i=1}^n z_{i,i}
# =\|A\|^2_2⋅\text{trace}(Z)
# =\|A\|^2_2⋅\text{trace}(Q^∗YQ)
# =\|A\|^2_2⋅\text{trace}(Y)
# =\|A\|^2_2⋅\text{trace}(B^*B)
# =\|A\|^2_2⋅\|B\|^2_F \Rightarrow \\
# \|AB\|_F \leq \|A\|_2⋅\|B\|_F $

# %% [markdown]
# And the final part: $\|AB\|_2 \leq \|AB\|_F \leq \|A\|_2⋅\|B\|_F $

# %% [markdown]
# #### 3.

# %% [markdown]
# ##### 1.(2 pts) Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$. Find a pseudoinverse of $UU^*$

# %% [markdown]
# - left inverse: $U^+=(U^*U)^{-1}U^*=I_kU^*=U^*$
# - right inverse: $U^+=U^*(U^*U)^{-1}=U^*I_k=U^*$

# %% [markdown]
# Properties of pseudoinverse: (https://en.wikipedia.org/wikiMoore%E2%80%93Penrose_inverse)
# - $(A^+)^+=A$
# - $(AB)^+=B^+A^+ \text{ if } B=A^*$

# %% [markdown]
# Then: $(UU^*)^+=(U^*)^+U^+=(U^+)^+U^+=UU^+=UU^*=I_n$

# %% [markdown]
# ##### 2.(3 pts) Compute pseudoinverse of the matrix analytically
#
# $$ A = \begin{bmatrix} 2\\ 3\\ \vdots\\ \sqrt{5n-1} \end{bmatrix} \begin{bmatrix} -1 & 1 & -1 & \ldots & (-1)^{n} \end{bmatrix} $$

# %% [markdown]
# ## Problem 2 (Matrix calculus) (15 pts)

# %% [markdown]
# 1. (11 pts) Consider the following function
# $$ F(U, V) = \frac{1}{2}\|X - UDV\|_F^2, $$
#
# where X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$, $V \in \mathbb{R}^{k \time$s n}$, $k < n$ and $D = diag(d_1, \ldots, d_k)$ is given diagonal matrix.
#
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $U$
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $V$
# - (7 pts) Estimate computational complexity of computing these gradients (in big-O notation). Also, compare timing of analytical computations versus timing the automatic differentiation with JAX. Study some range of dimensions to extract asymptotic complexity and make a conclusion, what approach is faster. Plot the dependence of running time on the dimension (row and column separately) to proof your conclusion
#
# 2. (4 pts) Derive analytical expression for the gradient and hessian of the function $f$:
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
# where $A$ is a symmetric real matrix. Why the gradient of this function is important in NLA you will know in the lectures later.

# %% [markdown]
# #### 1. (11 pts) Consider the following function
# $$ F(U, V) = \frac{1}{2}\|X - UDV\|_F^2, $$
#
# where $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$, $V \in \mathbb{R}^{k \times n}$, $k < n$ and $D = diag(d_1, \ldots, d_k)$ is given diagonal matrix.

# %% [markdown]
# $ F(U, V) = \frac{1}{2}\|X - UDV\|_F^2 = \frac{1}{2}\text{trace}((X-UDV)^T(X-UDV))=\frac{1}{2}\text{trace}((X^T-V^TD^TU^T)(X-UDV))=\frac{1}{2}\text{trace}(X^TX-V^TD^TU^TX-X^TUDV+V^TD^TU^TUDV)=
# \frac{1}{2}(\text{trace}(X^TX)-\text{trace}(V^TD^TU^TX)-\text{trace}(X^TUDV)+\text{trace}(V^TD^TU^TUDV))$

# %% [markdown]
# ##### 1.(2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $U$

# %% [markdown]
# According to the Matrix Cookbook: \
# $\frac{\partial }{\partial X}\text{Tr}(AXB)=A^TB^T \quad \quad \quad \quad (101)$ \
# $\frac{\partial }{\partial X}\text{Tr}(AX^TB)=BA \quad \quad \quad \quad \ \   (102)$ \
# $\frac{\partial }{\partial X}\text{Tr}(X^TXB)=XB^T+XB \ \ \ \   (113)$

# %% [markdown]
# $\nabla_U F
# =\frac{\partial }{\partial U} F
# =0.5(\frac{\partial }{\partial U}\text{Tr}(X^TX)-\frac{\partial }{\partial U}\text{Tr}(V^TD^TU^TX)-\frac{\partial }{\partial U}\text{Tr}(X^TUDV)+\frac{\partial }{\partial U}\text{Tr}(V^TD^TU^TUDV))
# =0.5 \left(-\frac{\partial }{\partial U}\text{Tr}((V^TD^T)U^T(X))-\frac{\partial }{\partial U}\text{Tr}((X^T)U(DV))+\frac{\partial }{\partial U}\text{Tr}(U^TU(DVV^TD^T)) \right)
# =0.5 \left(-(X)(V^TD^T))-(X^T)^T(DV)^T+U(DVV^TD^T)^T+U(DVV^TD^T) \right)=\
# =0.5 \left(-XV^TD^T-XV^TD^T+UDVV^TD^T+UDVV^TD^T \right)
# = UDVV^TD^T-XV^TD^T
# = (UDV-X)V^TD^T
# = (UDV-X)V^TD $

# %% [markdown]
# ##### 2.(2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $V$

# %% [markdown]
# According to the Matrix Cookbook: \
# $\frac{\partial }{\partial X}\text{Tr}(XA)=A^T \quad\quad\quad \quad \quad \quad (100)$ \
# $\frac{\partial }{\partial X}\text{Tr}(X^TA)=A \quad \quad \quad\quad \quad \quad   (103)$ \
# $\frac{\partial }{\partial X}\text{Tr}(XX^TB)=BX+B^TX \ \ \ \   (110)$

# %% [markdown]
# $\nabla_V F
# =\frac{\partial }{\partial V} F
# =0.5(\frac{\partial }{\partial V}\text{Tr}(X^TX)
# -\frac{\partial }{\partial V}\text{Tr}(V^TD^TU^TX)
# -\frac{\partial }{\partial V}\text{Tr}(X^TUDV)
# +\frac{\partial }{\partial V}\text{Tr}(V^TD^TU^TUDV))
# =0.5 \left(
# -\frac{\partial }{\partial V}\text{Tr}(V^T(D^TU^TX))
# -\frac{\partial }{\partial V}\text{Tr}(V(X^TUD))
# +\frac{\partial }{\partial V}\text{Tr}(VV^T(D^TU^TUD)) \right)
# =0.5 \left(
# -(D^TU^TX)
# -(X^TUD)^T)
# +(D^TU^TUD)V+(D^TU^TUD)^TV \right)
# = 0.5 \left(
# -D^TU^TX
# -D^TU^TX
# +(D^TU^TUD)V+(D^TU^TUD)V \right)
# =
# -D^TU^TX
# +D^TU^TUDV
# =
# -DU^TX
# +DU^TUDV
# =DU^T(UDV-X)$

# %% [markdown]
# ##### 3.(7 pts) Estimate computational complexity of computing these gradients (in big-O notation). Also, compare timing of analytical computations versus timing the automatic differentiation with JAX. Study some range of dimensions to extract asymptotic complexity and make a conclusion, what approach is faster. Plot the dependence of running time on the dimension (row and column separately) to proof your conclusion

# %% [markdown]
# $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$, $V \in \mathbb{R}^{k \times n}$, $k < n$ and $D = diag(d_1, \ldots, d_k)$ is given diagonal matrix.

# %% [markdown]
# Definition. A product of an $n \times k$ matrix $A$ and a $k \times m$ matrix $B$ is a $n \times m$ matrix $C$ with the elements
# $$ c_{ij} = \sum_{s=1}^k a_{is} b_{sj}, \quad i = 1, \ldots, n, \quad j = 1, \ldots, m $$
#
# For $m=k=n$ complexity of a naïve algorithm is $2n^3 - n^2 $ .

# %% [markdown]
# - $(UDV-X)V^TD$\
# $UD: O(nk)$, D - diagonal matrix\
# $(UD)V: O(n^2k)$\
# $(UDV)-X: O(n^2)$\
# $(UDV-X)V^T: O(n^2k+nk)=O(n^2k)$\
# $(UDV-X)V^T\cdot D: O(nk)$\
# in total: $O(n^2k)$
# - $DU^T(UDV-X)$\
# $DU^T: O(nk+nk)=O(nk). \quad k \times n$\
# $UDV-X: O(nk)+O(n^2k)+O(n^2)=O(n^2k). \quad n \times n$\
# $DU^T(UDV-X): O(n^2k)$\
# in total: $O(n^2k)$

# %% [markdown]
# #### 2. (4 pts) Derive analytical expression for the gradient and hessian of the function $f$:
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
# where $A$ is a symmetric real matrix.

# %% [markdown]
# $R(x) = \frac{A_{ij}x_jx_i}{x_kx_k}\\
# \frac{\partial R}{\partial x_n}
# = \frac{A_{in}x_i + A_{nj}x_j}{x_kx_k} - 2\frac{A_{ij}x_jx_i}{(x_kx_k)^2}x_n
# =|A_{ni}=A_{in}|= \frac{A_{ni}x_i + A_{nj}x_j}{x_kx_k} - 2\frac{A_{ij}x_jx_i}{(x_kx_k)^2}x_n
# = \frac{2Ax}{(x, x)} - 2 \frac{(Ax, x)}{(x, x)^2}x$

# %% [markdown]
# ## Problem 3. Compression of the fully-connected layers in neural network with simple architecture (30 pts)

# %% [markdown]
# In this problem we consider the neural network that performs classification of the dataset of images. Any neural network can be considered as composition of simple linear and non-linear functions. For example, a neural network with 3 layers can be represented as
# $$f_3(f_2(f_1(x, w_1), w_2), w_3),$$
#
# where $x$ is input data (in our case it will be images) and $w_i, \; i =1,\dots,3$ are parameters that are going to be trained.
#
# We will study the compression potential of neural network with simple architecture: alternating some numbers of linear and non-linear functions.
#
# The main task in this problem is to study how the compression of fully-connected layers affects the test accuracy. Any fully-connected layer is represented as linear function $AX + B$, where $X$ is input matrix and $A, B$ are trainable matrices. Matrices $A$ in every layer are going to be compressed. The main result that you should get is the plot of dependence of test accuracy on the total number of parameters in the neural network.

# %% [markdown]
# ##### **First step: download CIFAR10 dataset**

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %% [markdown]
# ##### **Check what images are we going to classify**

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
# horse  frog  frog  bird plane   cat   cat horse

# %% [markdown]
# ##### **Second step: neural network architecture**

# %% [markdown]
# For simplicity and demonstration purposes of the neural network compression idea consider the architecture consisting of the only fully-connected layers and non-linear ReLU functions between them. To demonstrate compression effect, consider the dimension of the inner layers equals to 1000.
#
# Below you see implementation of such neural network in PyTorch. More details about neural networks you will study in the Deep learning course in one of the upcoming term

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features, middle_features, activation=nn.ReLU()):
        super().__init__()
        self.layer1 = nn.Linear(in_features, middle_features)
        self.layer2 = nn.Linear(middle_features, in_features)
        self.activation = activation
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.activation(out)
        out = self.layer2(out)
        out = out + x
        out = self.activation(out)
        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.res1 = ResidualBlock(1000,1000)
        self.res2 = ResidualBlock(1000,1000)
        self.fc2 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.res1(x)
        x = self.res2(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# **Implement functions for training and testing after every sweep over all dataset entries**

# %%
def train(model, train_loader, optimizer, epoch):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.train()
    model.to(device)
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    device = "cuda" if torch.cuda.is_available() else "cpu"
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %% [markdown]
# **Set parameters for training and print intermediate loss values**

# %%
log_interval = 50
epochs = 7

# %% [markdown]
# ##### **Third step: run training with the Adam optimization method**

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.317122
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.758378
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.789747
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.714946
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.480283
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.572144
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.501521
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.512755
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.607798
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.377471
#
# Test set: Average loss: 1.4688, Accuracy: 4766/10000 (48%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.390729
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.458085
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.422711
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.433080
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.252364
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.342545
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.362352
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.435320
# ...
